# %% [markdown]
# # Eff. matching to GEN particle
#
#
#    * [Efficiency vs $\eta$](#Effinciency-vs-$\eta$)
#    * [Efficiency vs $p_{T}$](#Efficiency-vs-$p_{T}$)
#    * [Turn-on curves](#Turn-on-curves)

# %%
import sys
sys.path.insert(0, '..')
# sys.path.insert(1, '../python/')
sys.path.insert(1, 'python/')

import ROOT
import root_numpy as rnp
# import python.l1THistos as histos
import math
import uuid
import pandas as pd

from drawingTools import *

# ROOT.enableJSVis()
ROOT.enableJSVis()

#from drawingTools import *

normalized_histos = list()
# Out:
# Welcome to JupyROOT 6.24/02

# %%
# %load samples.py
import ROOT
import pandas as pd



samples = [
    HistoFile('doubleele_flat1to100_PU200_dtk', 'PU200', 'v149E.68A', 'float'),
    HistoFile('doubleele_flat1to100_PU200_dtk', 'PU200', 'v149E.68B', 'digitized'),
    HistoFile('doubleele_flat1to100_PU200_dtk', 'PU200', 'v149E.68C', 'digitized+ap.ext'),
]

# %%
# %load python/settings.py

# === samples =====================================================
import pprint
import python.plotters_config as plotters





for smp in samples:
    smp.open_file()

tps = [
    'PFDecTk',
]

# === Load the Histo Primitives ====================================
histo_primitives = samples[0].build_file_primitive_index()

# samples[0].print_file_primitive_index()


# print histo_primitives.data.unique()
# === TP selections ================================================
tp_select = {}

for tp in tps:
    tp_select[tp] = histo_primitives[histo_primitives.tp == tp].tp_sel.unique().tolist()

# ==== GEN selections ===============================================
gen_select ={}
for tp in tps:
    gen_select[tp] = histo_primitives[histo_primitives.tp == tp].gen_sel.unique().tolist()


import pprint
pp = pprint.PrettyPrinter(indent=4)
print ('--- TPs: ')
pp.pprint(tps)
print ('--- TP selections:')
pp.pprint(tp_select)
print ('--- GEN selections:')
pp.pprint(gen_select)
# Out:
# --- DecTkHistos
# # of plots: 480
# # of primitives: 30
# --- DecTkResoHistos
# # of plots: 168
# # of primitives: 12
# --- GenParticleHistos
# # of plots: 144
# # of primitives: 12
# --- TPs:
# ['PFDecTk']
# --- TP selections:
# {   'PFDecTk': [   'EtaCPt20',
#                    'EtaC',
#                    'all',
#                    'Pt20',
#                    'Pt10',
#                    'EtaAB',
#                    'EtaABCPt20',
#                    'EtaBPt20',
#                    'EtaBCPt10',
#                    'EtaABC',
#                    'EtaB',
#                    'EtaABPt20',
#                    'EtaABCPt10',
#                    'EtaBCPt20',
#                    'EtaBC',
#                    'EtaBPt10',
#                    'EtaCPt10',
#                    'EtaABPt10']}
# --- GEN selections:
# {'PFDecTk': ['nomatch', 'GENEePt30', 'GENEeEtaBC', 'GENEe', 'GENEePt15']}
# input_line_59:1:10: fatal error: 'src/fastfilling.h' file not found
# #include "src/fastfilling.h"
#          ^~~~~~~~~~~~~~~~~~~

# %%
import python.collections as collections
import python.selections as selections

labels_dict = {}

evm = collections.EventManager()
labels_dict.update(evm.get_labels())
selm = selections.SelectionManager()
labels_dict.update(selm.get_labels())



# #  ==== labels ===============================================
# tp_labels = histo_primitives[['data', 'data_label']].drop_duplicates().set_index('data').T.to_dict('records')[0]
# tp_selection_labels = histo_primitives[['data_sel', 'data_sel_label']].drop_duplicates().set_index('data_sel').T.to_dict('records')[0]
# gen_selection_labels = histo_primitives[['gen_sel', 'gen_sel_label']].drop_duplicates().set_index('gen_sel').T.to_dict('records')[0]

# %%
# print labels_dict.keys()

# %%
for tp in tps:
    print ('TP: {}'.format(tp))
    print (histo_primitives[histo_primitives.tp == tp].tp_sel.unique())
    print (histo_primitives[histo_primitives.tp == tp].gen_sel.unique())
# Out:
# TP: PFDecTk
# ['EtaCPt20' 'EtaC' 'all' 'Pt20' 'Pt10' 'EtaAB' 'EtaABCPt20' 'EtaBPt20'
#  'EtaBCPt10' 'EtaABC' 'EtaB' 'EtaABPt20' 'EtaABCPt10' 'EtaBCPt20' 'EtaBC'
#  'EtaBPt10' 'EtaCPt10' 'EtaABPt10']
# ['nomatch' 'GENEePt30' 'GENEeEtaBC' 'GENEe' 'GENEePt15']

# %%
# %%time

import python.l1THistos as histos

hplot = HPlot(samples, labels_dict)

hplot.create_histo_proxies(histos.HistoSetEff)
hplot.create_histo_proxies(histos.DecTkHistos)
hplot.create_histo_proxies(histos.DecTkResoHistos)

    
# for tp in tps:
#     hplot.cache_histo(classtype=histos.HistoSetEff, 
#                       samples=samples,
#                       pus=[],
#                       tps=[tp],
#                       tp_sels=histo_primitives[histo_primitives.data == tp].data_sel.unique(),
#                       gen_sels=gen_select[tp])
# Out:
# --- DecTkHistos
# # of plots: 480
# # of primitives: 30
# --- DecTkResoHistos
# # of plots: 168
# # of primitives: 12
# --- GenParticleHistos
# # of plots: 144
# # of primitives: 12
# --- DecTkHistos
# # of plots: 480
# # of primitives: 30
# --- DecTkResoHistos
# # of plots: 168
# # of primitives: 12
# --- GenParticleHistos
# # of plots: 144
# # of primitives: 12
# --- DecTkHistos
# # of plots: 480
# # of primitives: 30
# --- DecTkResoHistos
# # of plots: 168
# # of primitives: 12
# --- GenParticleHistos
# # of plots: 144
# # of primitives: 12
# --- DecTkHistos
# # of plots: 480
# # of primitives: 30
# --- DecTkResoHistos
# # of plots: 168
# # of primitives: 12
# --- GenParticleHistos
# # of plots: 144
# # of primitives: 12
# --- DecTkHistos
# # of plots: 480
# # of primitives: 30
# --- DecTkResoHistos
# # of plots: 168
# # of primitives: 12
# --- GenParticleHistos
# # of plots: 144
# # of primitives: 12
# --- DecTkHistos
# # of plots: 480
# # of primitives: 30
# --- DecTkResoHistos
# # of plots: 168
# # of primitives: 12
# --- GenParticleHistos
# # of plots: 144
# # of primitives: 12
# --- DecTkHistos
# # of plots: 480
# # of primitives: 30
# --- DecTkResoHistos
# # of plots: 168
# # of primitives: 12
# --- GenParticleHistos
# # of plots: 144
# # of primitives: 12
# --- DecTkHistos
# # of plots: 480
# # of primitives: 30
# --- DecTkResoHistos
# # of plots: 168
# # of primitives: 12
# --- GenParticleHistos
# # of plots: 144
# # of primitives: 12
# --- DecTkHistos
# # of plots: 480
# # of primitives: 30
# --- DecTkResoHistos
# # of plots: 168
# # of primitives: 12
# --- GenParticleHistos
# # of plots: 144
# # of primitives: 12
# CPU times: user 676 ms, sys: 36.6 ms, total: 713 ms
# Wall time: 737 ms

# %%
print (dir(samples[0]))
# samples[0].histo_file.ls()
samples
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'build_file_primitive_index', 'build_file_primitive_index_oldStyle', 'histo_file', 'histo_filename', 'label', 'name', 'oldStyle', 'open_file', 'print_file_primitive_index', 'print_primitives', 'type']
# [<HistoFile ../plots1/histos_doubleele_flat1to100_PU200_dtk_v149E.68A.root, float>,
#  <HistoFile ../plots1/histos_doubleele_flat1to100_PU200_dtk_v149E.68B.root, digitized>,
#  <HistoFile ../plots1/histos_doubleele_flat1to100_PU200_dtk_v149E.68C.root, digitized+ap.ext>]

# %%
hplot.data
# Out:
#                sample     pu       tp tp_sel     gen_sel  \
# 0               float  PU200  PFDecTk   Pt10   GENEePt30
# 1               float  PU200  PFDecTk   Pt20  GENEeEtaBC
# 2               float  PU200  PFDecTk   Pt20   GENEePt30
# 3               float  PU200  PFDecTk    all   GENEePt15
# 4               float  PU200  PFDecTk    all       GENEe
# ..                ...    ...      ...    ...         ...
# 157  digitized+ap.ext  PU200  PFDecTk   Pt20       GENEe
# 158  digitized+ap.ext  PU200  PFDecTk   Pt20   GENEePt15
# 159  digitized+ap.ext  PU200  PFDecTk   Pt10   GENEePt15
# 160  digitized+ap.ext  PU200  PFDecTk   Pt10       GENEe
# 161  digitized+ap.ext  PU200  PFDecTk   Pt20   GENEePt30
#
#                                       classtype  \
# 0        <class 'python.l1THistos.HistoSetEff'>
# 1        <class 'python.l1THistos.HistoSetEff'>
# 2        <class 'python.l1THistos.HistoSetEff'>
# 3        <class 'python.l1THistos.HistoSetEff'>
# 4        <class 'python.l1THistos.HistoSetEff'>
# ..                                          ...
# 157  <class 'python.l1THistos.DecTkResoHistos'>
# 158  <class 'python.l1THistos.DecTkResoHistos'>
# 159  <class 'python.l1THistos.DecTkResoHistos'>
# 160  <class 'python.l1THistos.DecTkResoHistos'>
# 161  <class 'python.l1THistos.DecTkResoHistos'>
#
#                                            histo
# 0    <drawingTools.HProxy object at 0x130e780a0>
# 1    <drawingTools.HProxy object at 0x130e5f280>
# 2    <drawingTools.HProxy object at 0x130e5f310>
# 3    <drawingTools.HProxy object at 0x130e5f5e0>
# 4    <drawingTools.HProxy object at 0x130e39fa0>
# ..                                           ...
# 157  <drawingTools.HProxy object at 0x130eae220>
# 158  <drawingTools.HProxy object at 0x130eaea00>
# 159  <drawingTools.HProxy object at 0x130eae610>
# 160  <drawingTools.HProxy object at 0x130eae4c0>
# 161  <drawingTools.HProxy object at 0x130eae8e0>
#
# [162 rows x 7 columns]

# %%
hplot.data['sample'].unique()
# Out:
# array(['float', 'digitized', 'digitized+ap.ext'], dtype=object)

# %%
hplot.data['tp'].unique()
# Out:
# array(['PFDecTk'], dtype=object)

# %%
hplot.data[hplot.data.tp == 'PFDecTk'].tp_sel.unique()
# Out:
# array(['Pt10', 'Pt20', 'all', 'EtaCPt20', 'EtaC', 'EtaAB', 'EtaABCPt20',
#        'EtaBPt20', 'EtaBCPt10', 'EtaABC', 'EtaB', 'EtaABPt20',
#        'EtaABCPt10', 'EtaBCPt20', 'EtaBC', 'EtaBPt10', 'EtaCPt10',
#        'EtaABPt10'], dtype=object)

# %%
# sample='ele'

# %% [markdown]
# ## Effinciency vs $\eta$

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.12, 0.15)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.HistoSetEff, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['all'], 'GENEePt15', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_eff.h_abseta.CreateGraph() for his in hsets], labels=labels)



dm.draw(text=text, 
        x_min=0., x_max=3.2, 
        y_min=0.5, y_max=1.1, v_lines=[1.52, 2.4],
        do_ratio=True,
        y_min_ratio=0.8,
        y_max_ratio=1.2)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')
# Out:
# <div id="root_plot_1627480660012"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1627480660012(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.13,"fRightMargin":0.3,"fBottomMargin":0.13,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.729824543791795,"fY1":0.398701299907667,"fX2":4.88421061437436,"fY2":1.1779220810134,"fXtoAbsPixelk":103.480046204376,"fXtoPixelk":103.480046204376,"fXtoPixel":141.787498220801,"fYtoAbsPixelk":864.673383510905,"fYtoPixelk":864.673383510905,"fYtoPixel":-734.066664890945,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-0.729824543791795,"fPixeltoXk":-0.729824543791795,"fPixeltoX":0.00705280798764592,"fAbsPixeltoYk":1.1779220810134,"fPixeltoYk":0.398701299907667,"fPixeltoY":-0.00136227409284219,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0.5,"fUxmax":3.2,"fUymax":1.1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0.5,"fX2":3.2,"fY2":1.1,"fBorderSize":1,"fBorderMode":0},{"_typename":"TGraphAsymmErrors","fUniqueID":0,"fBits":1032,"fName":"20985c","fTitle":"; |#eta^{GEN}|;","fLineColor":604,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":604,"fMarkerStyle":20,"fMarkerSize":1,"fNpoints":29,"fX":[0.25,0.35,0.45,0.55,0.65,0.75,0.85,0.95,1.05,1.15,1.25,1.35,1.45,1.55,1.65,1.75,1.85,1.95,2.05,2.15,2.25,2.35,2.45,2.55,2.65,2.75,2.85,2.95,3.05],"fY":[1,0.939098093909809,0.936295801314178,0.927198602213163,0.925294311805479,0.931136413400482,0.930905801198688,0.930425871099977,0.92548841435711,0.926250702641934,0.927072814989341,0.919760072430964,0.920693217032021,0.919476944253269,0.885493460166468,0.914324880054832,0.913068642203959,0.921602586306431,0.938775510204082,0.941779611078374,0.950419248997448,0.925287356321839,0.275134211810639,0.00122040517451794,0,0,0,0,0],"fFunctions":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fHistogram":{"_typename":"TH1F","fUniqueID":0,"fBits":512,"fName":"20985c","fTitle":"","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":102,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":" |#eta^{GEN}|","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1.4,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":100,"fXmin":0,"fXmax":3.2,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1.1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTi ...

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.12, 0.15)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.HistoSetEff, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['all'], 'GENEePt30', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_eff.h_abseta.CreateGraph() for his in hsets], labels=labels)


dm.draw(text=text, 
        x_min=0., x_max=3.2, 
        y_min=0.5, y_max=1.1, v_lines=[1.52, 2.4],
        do_ratio=True,
        y_min_ratio=0.8,
        y_max_ratio=1.2)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %% [markdown]
# ## Efficiency vs $p_{T}$

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.3, 0.1)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.HistoSetEff, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['all'], 'GENEeEtaBC', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_eff.h_pt.CreateGraph() for his in hsets], labels=labels)



dm.draw(
    text=text, 
    x_min=0, x_max=100, 
    y_min=0.0, y_max=1.1, 
    h_lines=[1.0, 0.9],
    do_ratio=True,
    y_min_ratio=0.8,
    y_max_ratio=1.2)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['EtaBC'], 'nomatch', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_pt for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(text=text, 
        x_min=0., x_max=100, 
#         y_min=0.5, y_max=1.1, v_lines=[1.52, 2.4],
        do_ratio=True,
        y_min_ratio=0.8,
        y_max_ratio=1.2)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['EtaC'], 'nomatch', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_pt for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(text=text, 
        x_min=0., x_max=100, 
#         y_min=0.5, y_max=1.1, v_lines=[1.52, 2.4],
        do_ratio=True,
        y_min_ratio=0.8,
        y_max_ratio=1.2)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['EtaBCPt10'], 'nomatch', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_deltaCaloEta for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
# dm.addRatioHisto(2,0)

dm.draw(text=text,
        options='hist',
#         x_min=0., x_max=100, 
#         y_min=0.5, y_max=1.1, v_lines=[1.52, 2.4],
        do_ratio=True,
        y_min_ratio=0.8,
        y_max_ratio=1.2,
       y_log=True)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['EtaBCPt10'], 'nomatch', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_deltaCaloPhi for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(text=text,
        options='hist',
        y_min=1., y_max=40000, 
#         y_min=0.5, y_max=1.1, v_lines=[1.52, 2.4],
        do_ratio=True,
        y_min_ratio=0.8,
        y_max_ratio=1.2,
       y_log=True)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['EtaBCPt10'], 'nomatch', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_deltaZ0 for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(text=text,
        options='hist',
#         y_min=1., y_max=40000, 
#         y_min=0.5, y_max=1.1, v_lines=[1.52, 2.4],
        do_ratio=True,
        y_min_ratio=0.8,
        y_max_ratio=1.2,
       y_log=False)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['EtaBCPt10'], 'nomatch', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_deltaPt for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(text=text,
        options='hist',
#         x_min=0., x_max=100, 
#          y_min=-0.2, y_max=0.2, 
        h_lines=[0, -0.01, 0.01],
        do_ratio=False,
        y_min_ratio=0.8,
        y_max_ratio=1.2,
       y_log=False,
       do_profile=False)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['EtaBCPt10'], 'nomatch', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)

for idx in range(0, len(hsets)):
    hsets[idx].h_deltaPtVeta = hsets[idx].h_deltaPtVeta.RebinX(2)


dm.addHistos([his.h_deltaPtVeta for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(text=text,
        options='COLZ',
#         x_min=0., x_max=100, 
         y_min=-0.2, y_max=0.2, 
        h_lines=[0],
        do_ratio=False,
        y_min_ratio=0.8,
        y_max_ratio=1.2,
       y_log=False,
       do_profile=True)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['EtaBCPt10'], 'nomatch', debug=False)


for idx in range(0, len(hsets)):
    hsets[idx].h_deltaEtaVeta = hsets[idx].h_deltaEtaVeta.RebinX(2)


# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_deltaEtaVeta for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(text=text,
        options='COLZ',
#         x_min=0., x_max=100, 
        y_min=-0.05, y_max=0.05, 
        h_lines=[0, -0.01, 0.01],
        do_ratio=False,
        y_min_ratio=0.8,
        y_max_ratio=1.2,
       y_log=False,
       do_profile=True)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['EtaBCPt10'], 'nomatch', debug=False)

for idx in range(0, len(hsets)):
    hsets[idx].h_deltaZ0Veta = hsets[idx].h_deltaZ0Veta.RebinX(2)

dm.addHistos([his.h_deltaZ0Veta for his in hsets], labels=labels)

# dm.addRatioHisto(1,0)
# dm.addRatioHisto(2,0)

dm.draw(text=text,
        options='COLZ',
#         x_min=0., x_max=100, 
        y_min=-0.05, y_max=0.05, 
        h_lines=[0, -0.01, 0.01],
        do_ratio=False,
        y_min_ratio=0.8,
        y_max_ratio=1.2,
       y_log=False,
       do_profile=True)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['EtaBCPt10'], 'nomatch', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_deltaEtaVeta for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(text=text,
        options='COLZ',
#         x_min=0., x_max=100, 
        y_min=-0.05, y_max=0.05, 
        h_lines=[0, -0.01, 0.01],
        do_ratio=False,
        y_min_ratio=0.8,
        y_max_ratio=1.2,
       y_log=False,
       do_profile=True)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['EtaBCPt10'], 'nomatch', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_deltaCaloEtaVabseta for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(text=text,
        options='COLZ',
#         x_min=0., x_max=100, 
        y_min=-0.05, y_max=0.05, 
        h_lines=[0],
        do_ratio=False,
        y_min_ratio=0.8,
        y_max_ratio=1.2,
       y_log=False)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['EtaBCPt10'], 'nomatch', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_deltaCaloEtaVeta for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(text=text,
        options='COLZ',
#         x_min=0., x_max=100, 
        y_min=-0.05, y_max=0.05, 
        h_lines=[0, -0.01, 0.01],
        do_ratio=False,
        do_profile=True,
        y_min_ratio=0.8,
        y_max_ratio=1.2,
       y_log=False)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['EtaBCPt10'], 'nomatch', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_deltaCaloEtaVabseta for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(text=text,
        options='COLZ',
#         x_min=0., x_max=100, 
        y_min=-0.05, y_max=0.05, 
        h_lines=[0],
        do_ratio=False,
        y_min_ratio=0.8,
        y_max_ratio=1.2,
       y_log=False)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkResoHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['all'], 'GENEeEtaBC', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_caloEtaRes for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(
    text=text,
    options='hist',
    x_min=-0.2, x_max=0.2, 
#         y_min=-0.05, y_max=0.05, 
    h_lines=[0],
    do_ratio=True,
    y_min_ratio=0.8,
    y_max_ratio=1.2,
    y_log=False)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkResoHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['all'], 'GENEeEtaBC', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_caloEtaResVabseta for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(
    text=text,
    options='COLZ',
    x_min=1.5, x_max=2.5, 
    y_min=-0.15, y_max=0.15, 
    h_lines=[0],
    do_ratio=False,
    y_min_ratio=0.8,
    y_max_ratio=1.2,
    y_log=False)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkResoHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['Pt10'], 'GENEeEtaBC', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_etaResVeta for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(
    text=text,
    options='COLZ',
    x_min=1.5, x_max=2.5, 
    y_min=-0.05, y_max=0.05, 
    h_lines=[0, -0.01, 0.01],
    do_ratio=False,
    do_profile=True,
    y_min_ratio=0.8,
    y_max_ratio=1.2,
    y_log=False)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkResoHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['all'], 'GENEeEtaBC', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_caloEtaResVeta for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(
    text=text,
    options='COLZ',
    x_min=1.5, x_max=2.5, 
    y_min=-0.05, y_max=0.05, 
    h_lines=[0, -0.01, 0.01],
    do_ratio=False,
    y_min_ratio=0.8,
    y_max_ratio=1.2,
    y_log=False)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkResoHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['all'], 'GENEeEtaBC', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_caloPhiRes for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(
    text=text,
    options='hist',
    x_min=-0.2, x_max=0.2, 
#         y_min=-0.05, y_max=0.05, 
    h_lines=[0],
    do_ratio=True,
    y_min_ratio=0.8,
    y_max_ratio=1.2,
    y_log=False)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')

# %%
newconfig=rleg_config
newconfig.marker_size = 1
newconfig.legend_size=(0.5, 0.3)
newconfig.legend_position=(0.5, 0.5)
newconfig.marker_styles.append(10)
dm = DrawMachine(newconfig)

hsets, labels, text = hplot.get_histo(
    histos.DecTkResoHistos, 
    ['float', 'digitized', 'digitized+ap.ext'], 
    ['PU200'], 
    ['PFDecTk'], 
    ['all'], 'GENEeEtaBC', debug=False)
# for hset in hsets:
#     hset.computeEff(rebin=2)
dm.addHistos([his.h_caloPhiResVabseta for his in hsets], labels=labels)

dm.addRatioHisto(1,0)
dm.addRatioHisto(2,0)

dm.draw(
    text=text,
    options='COLZ',
    x_min=1.5, x_max=2.5, 
    y_min=-0.4, y_max=0.4, 
    h_lines=[0],
    do_ratio=False,
    y_min_ratio=0.8,
    y_max_ratio=1.2,
    y_log=False)
# dm.write(name='eg_TDRvsSummer20_matchig_eff')
